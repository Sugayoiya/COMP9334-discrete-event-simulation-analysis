# %%
server_state = {'0':'OFF','1':'SETUP','2':'BUSY','3':'DELAYEDOFF'}
job_state = {'0':'MARKED', '1':'UNMARKED'}
import random


class job():
    def __init__(self,t,which_server,m):
        self.state = str(m)
        self.num = str(which_server)
        self.time = t

# def simulation_system(arrival_time,service_time,m_server,setup_time):
#     master_clock = 0
#     # set OFF initialize server
#     server = dict([(str(key), '0') for key in range(1,m_server+1)])
#     # set empty queue dispatcher
#     dispatcher = queue.Queue()
#     flag = 0
#     if len(arrival_time) != 0:
#         flag = 1
#     print('server state and flag:',server,flag)
#     next_event = [] # control master clock
#     while flag == 1:
#         check_server_state = []
#         next_event.append((arrival_time.pop(0),'arrival'))
#         master_clock = next_event.pop(0)
# #         print(master_clock)
#         for i in server:
#             if server[i]=='3': # delayedoff
#                 check_server_state.append(i)
#         if len(check_server_state) == 0:
#             for i in server:
#                 if server[i]=='0': # off
#                     check_server_state.append(i)
#             print('off server is listed :',check_server_state)
#             server[check_server_state[random.randint(0,len(check_state))-1]] = '1' # change off to setup
#             dispatcher.put(job(master_clock[0],check_server_state[random.randint(0,len(check_state))-1],'MARKED'))
#             next_event.append((master_clock[0]+setup_time,'SETUP'))

#         print('each server, server state, next_event:',server,server_state[dispatcher.get().state],next_event)
        
        
# simulation_system([1,2,3],2,5,80)

# %%
dict.fromkeys([1, 2, 3, 4])
import random



class job():
    def __init__(self,m = 'MARKED'):
        self.state = m

# %%
import queue
import random
from collections import defaultdict

server_state = {'0':'OFF','1':'SETUP','2':'BUSY','3':'DELAYEDOFF'}
job_state = {'0':'MARKED', '1':'UNMARKED'}

class job():
    def __init__(self,t,num,m):
        self.state = str(m)
        self.num = str(num)
        self.time = t

def simulation(arrival,service,m,setup,delayoff,time_end = 0.0):
    pass


# -----------reading num of tests parameters-------------
        
with open('num_tests.txt','r') as num:
    for i in num:
        tests = int(i.strip())
        print('num of tests:',tests)
num.close()
    
## read file method

def read_para_trace():  
    with open(para_file,'r') as para:
        para_list = []
        for i in para:
            para_list.append(i.strip())
        servers,setup,delayoff = para_list[:] 
#         print('servers,setup,delayoff:',servers,setup,delayoff)
    para.close()
    
    with open(arrival_file,'r') as arr:
        arr_list =[]
        for i in arr:
            arr_list.append(int(i.strip()))
#         print('arrival:',arr_list)
    arr.close()
    
    with open(service_file,'r') as service:
        ser_list = []
        for i in service:
            ser_list.append(int(i.strip()))
#         print('service:',ser_list)
    service.close()
    return servers,setup,delayoff,arr_list,ser_list

def read_para_random():  
    with open(para_file,'r') as para:
        para_list = []
        for i in para:
            para_list.append(i.strip())
        servers,setup,delayoff,time_end = para_list[:] 
#         print('servers,setup,delayoff,time_end:',servers,setup,delayoff,time_end)
    para.close()
    
    with open(arrival_file,'r') as arr:
        for i in arr:
            arr_list = (float(i.strip()))
#         print('arrival:',arr_list)
    arr.close()
    
    with open(service_file,'r') as service:
        for i in service:
            ser_list = (float(i.strip()))
#         print('service:',ser_list)
    service.close()
    return servers,setup,delayoff,time_end,arr_list,ser_list

## read file method ends

for i in range(1,tests+1):
    mode_file = 'mode_{}.txt'.format(i) 
    para_file = 'para_{}.txt'.format(i)
    arrival_file = 'arrival_{}.txt'.format(i)
    service_file = 'service_{}.txt'.format(i)
#     print(mode_file,para_file,arrival_file,service_file)
    
    with open(mode_file,'r') as mode:
        for j in mode:
            print('test {}:'.format(i))
            if j=='trace':
                servers,setup,delayoff,arr_list,ser_list = read_para_trace()
                print('servers,setup,delayoff,arr_list,ser_list:',
                      servers,setup,delayoff,arr_list,ser_list)
                # do trace simulation
            else:
                servers,setup,delayoff,time_end,arr_list,ser_list = read_para_random()
                print('servers,setup,delayoff,time_end,arr_list,ser_list:',
                      servers,setup,delayoff,time_end,arr_list,ser_list)
                # do random simulation
    mode.close()



# -----------------------end-------------------------
# Out:
# num of tests: 2
# test 1:
# servers,setup,delayoff,arr_list,ser_list: 3 50 100 [10, 20, 32, 33] [1, 2, 3, 4]
# test 2:
# servers,setup,delayoff,time_end,arr_list,ser_list: 3 50 100 1000 0.35 1.0

# %%
from collections import Counter

server_state1 = {'0':'OFF','1':'SETUP','2':'BUSY','3':'DELAYEDOFF','4':'BUSY_JOB_NOT_IN_QUEUE'}
job_state = {'0':'MARKED', '1':'UNMARKED'}

server_state = defaultdict(list)  # { server num:['state',time] } 
event = [] # sorted by time -includes setup, arrival and complete
master_clock = 0.0
# arrival = [10, 20, 32, 33] 
# service = [1, 2, 3, 4]
arrival,service = generate_exp(2000,0.35,1)
respose_time = 0
delayedoff  = 100.0  # delayedoff time to off state
depatcher_queue = []  # jobs in the queue
check_state = 0  
job_num = 1
setup_time = 50.0  # the time needed setting up an off server to process a job
complete_time = [] # ordered by arrival time
mrt = 0.0

m = 3 # num of servers
for i in range(1, m+1): # initialize
    server_state[i].append('0')
    server_state[i].append(0)

# arrival = [11, 11.2, 11.3, 13] 
# service = [1, 1.4, 5, 1]
# # initialize
# server_state[1].append('3')
# server_state[1].append(20) 
# server_state[2].append('3')
# server_state[2].append(17) 
# server_state[3].append('0')
# server_state[3].append(0) 
    
ll=server_state
server_state # server num:[ state, time(default = 0)]
for x in arrival:
    event.append((x,'arrival'))
    
def check_server(server_state): # check number of each state of servers
    count = []
    for  i in server_state:
        count.append(server_state[i][0])
    return Counter(count)
    
def check_job(depatcher_queue): # check jobs two states
    count = []
    for i in depatcher_queue:
        count.append(i.state)
    return Counter(count)

def find_server_num(server_state,time): 
    for i in server_state:
        if server_state[i][1] == time:
            return i
        
def find_longest_setup(server_state):
    time = 0
    num = 0
    for i in server_state:
        if server_state[i][0] == '1':
            if server_state[i][1] > time:
                time = server_state[i][1]
                num = i
    return num

def find_longest_delayedoff(server_state,master_clock):
    num = 0
    time = 0
    for i in server_state:
        if server_state[i][0] == '3':
            if server_state[i][1] - master_clock > time:
                time = server_state[i][1] - master_clock
                num = i
    print(num)
    return num
            
print('event:',event,'\n')

while len(event)!=0:
    event.sort(key = lambda x: x[0],reverse = False) # sorted event list by time
    event_now = event.pop(0)
    time_passed = event_now[0] - master_clock
    master_clock = event_now[0]
    print('-----------------------  -----------------------')
    print('event:',event,'\n')

    if event_now[1] =='arrival':
    #     print('arrival')

        check_server_state = check_server(server_state)
        print(check_server_state)
    #     print(set(check_state)) 
        check_job_state = check_job(depatcher_queue)
        print(check_job_state)
        
        if '3' in set(check_server_state): # at least one delayedoff server
            depatcher_queue.append(job(event_now[0],job_num,'Delayed'))
            delayedoff_to_busy = find_longest_delayedoff(server_state,master_clock)
            server_state[delayedoff_to_busy][0] = '4'
            temp = master_clock + service[job_num-1]
            depatcher_queue.pop()
            complete_time.append(temp)
            server_state[delayedoff_to_busy][1] = temp
            event.append((temp,'completed'))
            
            print('server_state:\n',server_state,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\n\nmaster_clock:',master_clock,'\n')
            print('event:',event,'\n')
            job_num += 1
            continue
        
        elif '0' in set(check_server_state): # random choose one off server to setup
            depatcher_queue.append(job(event_now[0],job_num,'MARKED'))
            job_num += 1
#             print(server_state)
            off_servers = [] # off state
            for i in server_state:
                if server_state[i][0] =='0':
                    off_servers.append(i)
            temp = off_servers[random.randint(0,len(off_servers)-1)]
            server_state[temp][0]= '1'
            server_state[temp][1] = master_clock+setup_time
            event.append((master_clock+setup_time,'setup')) # what time setup finished
            
            print('server_state:\n',server_state,'\n\ndepatcher_queue:\n',
                  
                  [(i.num,i.state) for i in depatcher_queue],'\n\nmaster_clock:',master_clock,'\n')
            print('event:',event,'\n')

            continue
            
        else: # all busy (need to be inplemented)
            depatcher_queue.append(job(event_now[0],job_num,'UNMARKED'))
            print('server_state:\n',server_state,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\n\nmaster_clock:',master_clock,'\n')
            print('event:',event,'\n')
            job_num += 1
            continue

    
    if event_now[1] =='setup': # time for this server to do job
#         print('setup server is :',find_server_num(server_state, master_clock))
        temp = find_server_num(server_state, master_clock)
        server_state[temp][0]= '2'
        busy_time = master_clock+service[int(depatcher_queue.pop(0).num)-1]
        complete_time.append(busy_time)
        server_state[temp][1] = busy_time
        
        event.append((busy_time,'completed')) # what time job completed
        print('event(setup):',event,'\n','\n\ndepatcher_queue:\n',
              [(i.num,i.state) for i in depatcher_queue],
              'server_state:\n',server_state,'\n\nmaster_clock:',master_clock,'\n')
        continue
    
    if event_now[1] =='completed':
        temp = find_server_num(server_state, master_clock) # num of server which completed job
        
        check_job_state = check_job(depatcher_queue)
        print('completed a job,',check_job_state,'\n')
        if 'MARKED' in check_job_state:
            print('\nthere are still marked jobs in queue\n')
            server_state[temp][0]= '2'
            busy_time = master_clock+service[int(depatcher_queue.pop(0).num)-1] # job in the front 
            complete_time.append(busy_time)
            server_state[temp][1] = busy_time           
            
            event.append((busy_time,'completed')) # what time job completed
            
            if 'UNMARKED' in check_job_state:
                # still some unmarked remain --> unmarked changed to marked
                for i in depatcher_queue:
                    if i.state =='UNMARKED':
                        i.state = 'MARKED'
                        break
            else:
                # no unmarked remain --> marked -1 setup -1
                server_to_off = int(find_longest_setup(server_state))
                print('server_to_off:',server_to_off,'\n',server_state)
                for i in range(len(event)):
                    print(event[i],server_state[server_to_off])
                    if event[i] == (server_state[server_to_off][1],'setup'):
    #                     event.pop((server_state[server_to_off][1],'setup'))
                        print(event.pop(i))
                        break
                server_state[server_to_off][0]= '0'
                server_state[server_to_off][1]= 0
            
            print('event(complete,marked):',event,'\n','\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'server_state:\n',server_state,
                  '\n\nmaster_clock:',master_clock,'\n')
            continue
        elif 'UNMARKED' in check_job_state:
            print('\nthere are unmarked jobs in queue\n')
            server_state[temp][0]= '2'
            busy_time = master_clock+service[int(depatcher_queue.pop(0).num)-1]
            complete_time.append(busy_time)
            server_state[temp][1] = busy_time
            event.append((busy_time,'completed')) # what time job completed
#             print('\nprocessing job {} server time is {}'.format(depatcher_queue [0].num,busy_time-master_clock))
            print('event(complete,unmarked):',event,'\n','\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'server_state:\n',server_state,
                  '\n\nmaster_clock:',master_clock,'\n')
            continue
        else:
            print('\nno jobs in queue\n')
            server_state[temp][0]= '3'
            delayedoff_time = master_clock+delayedoff
            server_state[temp][1] = delayedoff_time
#             print('\n processing job {} server time is {}'.format(depatcher_queue[0].num,busy_time-master_clock))
            print('event(complete,else):',event,'\n','\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'server_state:\n',server_state,
                  '\n\nmaster_clock:',master_clock,'\n')
            continue
        
# mean response time
for i in range(len(arrival)):
    mrt += complete_time[i]-arrival[i]
mrt = ('%.3f' %(mrt/len(arrival))) # mean response time

print('\nfinished!\n','each jobs finished at:',complete_time,'mrt is :',mrt)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [(516.4958085613715, 'arrival'), (519.001603573647, 'arrival'), (519.8253824249587, 'completed'), (520.0079574660891, 'arrival'), (525.671565309074, 'arrival'), (526.6968293549965, 'arrival'), (526.7344067887615, 'arrival'), (527.0551717359043, 'arrival'), (527.9711036491777, 'arrival'), (528.7867184009859, 'arrival'), (536.1522892353387, 'arrival'), (537.2182918121116, 'arrival'), (538.112475303988, 'arrival'), (541.243961137103, 'arrival'), (545.2096861710037, 'arrival'), (548.9012456121903, 'arrival'), (553.446706372483, 'arrival'), (556.1539896021216, 'arrival'), (560.0636880585527, 'arrival'), (567.1100124712077, 'arrival'), (567.9529241777545, 'arrival'), (569.9362669938618, 'arrival'), (571.7560218245469, 'arrival'), (571.9012141065431, 'arrival'), (582.6315262926097, 'arrival'), (584.9882999127925, 'arrival'), (587.0753204805548, 'arrival'), (587.4090195757087, 'arrival'), (587.9388232809271, 'arrival'), (590.0432544210231, 'arrival'), (594.1493437551644, 'arrival'), (594.1889968924895, 'arrival'), (597.7629890613392, 'arrival'), (599.7141804712829, 'arrival'), (600.5475881015126, 'arrival'), (600.7543402796002, 'arrival'), (605.4450901421698, 'arrival'), (607.4388
447631, 'arrival'), (770.236422241453, 'arrival'), (771.3558911161316, 'arrival'), (772.9087678317285, 'arrival'), (773.3089285688205, 'arrival'), (776.4628364351055, 'arrival'), (777.0403144205529, 'arrival'), (781.2094104307118, 'arrival'), (781.8730506440866, 'arrival'), (782.6763529976197, 'arrival'), (788.3199558866053, 'arrival'), (788.9332457518688, 'arrival'), (789.7534259079413, 'arrival'), (793.6947026493553, 'arrival'), (796.3404941111373, 'arrival'), (798.5076102570179, 'arrival'), (800.4914482097588, 'arrival'), (800.991230326548, 'arrival'), (809.2843145994848, 'arrival'), (814.2867091709392, 'arrival'), (814.7472647522462, 'arrival'), (815.3145686356798, 'arrival'), (815.82828994602, 'arrival'), (816.2232533957641, 'arrival'), (819.6655402055223, 'arrival'), (821.2232419682562, 'arrival'), (823.338558987372, 'arrival'), (831.9291186226758, 'arrival'), (832.304107463082, 'arrival'), (835.5450147111504, 'arrival'), (853.626718675031, 'arrival'), (857.815652766423, 'arrival'), (862.7852905784378, 'arrival'), (866.4836588869251, 'arrival'), (868.997332172831, 'arrival'), (869.7078355920708, 'arrival'), (871.3747948648231, 'arrival'), (872.147270053785, 'arrival'), (873.489646827925, 'arrival'), (877.467689333591, 'arrival'), (886.7284239490945, 'arrival'), (887.6498558801378, 'arrival'), (887.7964548858591, 'arrival'), (889.7963759652032, 'arrival'), (892.5975598326389, 'arrival'), (893.6196121781752, 'arrival'), (898.7188044736139, 'arrival'), (903.332809799713, 'arrival'), (903.8298945128588, 'arrival'), (904.941334549837, 'arrival'), (913.8448995150219, 'arrival'), (916.8276766520696, 'arrival'), (916.8862740313411, 'arrival'), (917.7566128739968, 'arrival'), (919.4437741192213, 'arrival'), (925.5697585563399, 'arrival'), (933.4600719382773, 'arrival'), (933.5782658599536, 'arrival'), (939.0875126439888, 'arrival'), (944.8303671992041, 'arrival'), (945.0416775417619, 'arrival'), (946.211865118369, 'arrival'), (951.1366103444611, 'arrival'), (951.4378911745683, 'arriv ...
#
#
# depatcher_queue:
#  []
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import random 
random.expovariate(1)
def generate_exp(T_end, arrival, service):
    arrival_list = []
    service_list = []
    arr , ser = 0.0, 0.0 
    arr += random.expovariate(arrival)
    while arr<= T_end:
        arrival_list.append(arr)
        ser = random.expovariate(service)+random.expovariate(service)+random.expovariate(service)
        service_list.append(ser)
        arr += random.expovariate(arrival)
    return arrival_list,service_list
    print(len(arrival_list) == len(service_list))
# arr,ser = generate_exp(200,0.35,1)

# %%
L = [1,2,3,4]
L.pop()

1/(1-0.35)
# Out:
# 1.5384615384615383

# %%
from collections import Counter

server_state1 = {'0':'OFF','1':'SETUP','2':'BUSY','3':'DELAYEDOFF','4':'BUSY_JOB_NOT_IN_QUEUE'}
job_state = {'0':'MARKED', '1':'UNMARKED'}

server_state = defaultdict(list)  # { server num:['state',time] } 
event = [] # sorted by time -includes setup, arrival and complete
master_clock = 0.0
arrival = [10, 20, 32, 33] 
service = [1, 2, 3, 4]
# arrival,service = generate_exp(50000,0.7,1)
respose_time = 0
delayedoff  = 100.0  # delayedoff time to off state (Tc)
depatcher_queue = []  # jobs in the queue
check_state = 0  
job_num = 1
setup_time = 50.0  # the time needed setting up an off server to process a job
complete_time = [] # ordered by arrival time
mrt = 0.0

m = 3 # num of servers
for i in range(1, m+1): # initialize
    server_state[i].append('0')
    server_state[i].append(0)

# arrival = [11, 11.2, 11.3, 13] 
# service = [1, 1.4, 5, 1]
# # initialize
# server_state[1].append('3')
# server_state[1].append(20) 
# server_state[2].append('3')
# server_state[2].append(17) 
# server_state[3].append('0')
# server_state[3].append(0) 
    
ll=server_state
server_state # server num:[ state, time(default = 0)]
for x in arrival:
    event.append((x,'arrival'))
    
def check_server(server_state): # check number of each state of servers
    count = []
    for  i in server_state:
        count.append(server_state[i][0])
    return Counter(count)
    
def check_job(depatcher_queue): # check jobs two states
    count = []
    for i in depatcher_queue:
        count.append(i.state)
    return Counter(count)

def find_server_num(server_state,time): 
    for i in server_state:
        if server_state[i][1] == time:
            return i
        
def find_longest_setup(server_state):
    time = 0
    num = 0
    for i in server_state:
        if server_state[i][0] == '1':
            if server_state[i][1] > time:
                time = server_state[i][1]
                num = i
    return num

def find_longest_delayedoff(server_state,master_clock):
    num = 0
    time = 0
    real_time = 0
    for i in server_state:
        if server_state[i][0] == '3':
#             print(i,server_state[i][1],master_clock)
            if server_state[i][1] - master_clock > time:
                time = server_state[i][1] - master_clock
                num = i
                real_time = server_state[i][1]
#     print(num,real_time)
    return num,real_time

def find_delayedoff_server(server_state,time):
    for i in server_state:
        if server_state[i][1] == time:
            return i
            
print('event:',event,'\n')

while len(event)!=0:
    event.sort(key = lambda x: x[0],reverse = False) # sorted event list by time
    event_now = event.pop(0)
    time_passed = event_now[0] - master_clock
    master_clock = event_now[0]
    print('-----------------------  -----------------------')
#     print('event:',event,'\n')

    if event_now[1] =='arrival':
    #     print('arrival')

        check_server_state = check_server(server_state)
#         print(check_server_state)
    #     print(set(check_state)) 
        check_job_state = check_job(depatcher_queue)
#         print(check_job_state)
        
        if '3' in set(check_server_state): # at least one delayedoff server
            depatcher_queue.append(job(event_now[0],job_num,'Delayed'))
            delayedoff_to_busy,time = find_longest_delayedoff(server_state,master_clock)
            server_state[delayedoff_to_busy][0] = '4'
            temp = master_clock + service[job_num-1]
            depatcher_queue.pop()
#             print(len(event))
            for i in range(len(event)):
#                 print(i)
                if event[i] == (time,'delayedoff'):
                    event.pop(i)
                    break
            complete_time.append(temp)
            server_state[delayedoff_to_busy][1] = temp
            event.append((temp,'completed'))
            
            print('event:\n',event,'\nserver_state:\n',server_state,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\n\nmaster_clock:',master_clock,'\n')
            job_num += 1
            continue
        
        elif '0' in set(check_server_state): # random choose one off server to setup
            depatcher_queue.append(job(event_now[0],job_num,'MARKED'))
            job_num += 1
#             print(server_state)
            off_servers = [] # off state
            for i in server_state:
                if server_state[i][0] =='0':
                    off_servers.append(i)
            temp = off_servers[random.randint(0,len(off_servers)-1)]
            server_state[temp][0]= '1'
            server_state[temp][1] = master_clock+setup_time
            event.append((master_clock+setup_time,'setup')) # what time setup finished
            
            print('event:\n',event,'\nserver_state:\n',server_state,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\n\nmaster_clock:',master_clock,'\n')

            continue
            
        else: # all busy (need to be inplemented)
            depatcher_queue.append(job(event_now[0],job_num,'UNMARKED'))
            print('event:\n',event,'\nserver_state:\n',server_state,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\n\nmaster_clock:',master_clock,'\n')
            job_num += 1
            continue

    
    if event_now[1] =='setup': # time for this server to do job
#         print('setup server is :',find_server_num(server_state, master_clock))
        temp = find_server_num(server_state, master_clock)
        server_state[temp][0]= '2'
        busy_time = master_clock+service[int(depatcher_queue.pop(0).num)-1]
        complete_time.append(busy_time)
        server_state[temp][1] = busy_time
        
        event.append((busy_time,'completed')) # what time job completed
        print('event(setup):\n',event,'\ndepatcher_queue:\n',
              [(i.num,i.state) for i in depatcher_queue],
              '\nserver_state:\n',server_state,'\n\nmaster_clock:\n',master_clock,'\n')
        continue
    
    if event_now[1] =='completed':
        temp = find_server_num(server_state, master_clock) # num of server which completed job
        
        check_job_state = check_job(depatcher_queue)
#         print('completed a job,',check_job_state,'\n')
        if 'MARKED' in check_job_state:
#             print('\nthere are still marked jobs in queue\n')
            server_state[temp][0]= '2'
            busy_time = master_clock+service[int(depatcher_queue.pop(0).num)-1] # job in the front 
            complete_time.append(busy_time)
            server_state[temp][1] = busy_time           
            
            event.append((busy_time,'completed')) # what time job completed
            
            if 'UNMARKED' in check_job_state:
                # still some unmarked remain --> unmarked changed to marked
                for i in depatcher_queue:
                    if i.state =='UNMARKED':
                        i.state = 'MARKED'
                        break
            else:
                # no unmarked remain --> marked -1 setup -1
                server_to_off = int(find_longest_setup(server_state))
#                 print('server_to_off:',server_to_off,'\n',server_state)
                for i in range(len(event)):
#                     print(event[i],server_state[server_to_off])
                    if event[i] == (server_state[server_to_off][1],'setup'):
    #                     event.pop((server_state[server_to_off][1],'setup'))
                        event.pop(i)
                        break
                server_state[server_to_off][0]= '0'
                server_state[server_to_off][1]= 0
            
            print('event(complete,marked)\n:',event,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\nserver_state:\n',server_state,
                  '\n\nmaster_clock:\n',master_clock,'\n')
            continue
        elif 'UNMARKED' in check_job_state:
#             print('\nthere are unmarked jobs in queue\n')
            server_state[temp][0]= '2'
            busy_time = master_clock+service[int(depatcher_queue.pop(0).num)-1]
            complete_time.append(busy_time)
            server_state[temp][1] = busy_time
            event.append((busy_time,'completed')) # what time job completed
#             print('\nprocessing job {} server time is {}'.format(depatcher_queue [0].num,busy_time-master_clock))
            print('event(complete,unmarked):\n',event,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\nserver_state:\n',server_state,
                  '\n\nmaster_clock:\n',master_clock,'\n')
            continue
        else:
#             print('\nno jobs in queue\n')
            server_state[temp][0]= '3'
            delayedoff_time = master_clock+delayedoff
            server_state[temp][1] = delayedoff_time
            event.append((delayedoff_time,'delayedoff')) # delayedoff
#             print('\n processing job {} server time is {}'.format(depatcher_queue[0].num,busy_time-master_clock))
            print('event(complete,else):\n',event,'\n\ndepatcher_queue:\n',
                  [(i.num,i.state) for i in depatcher_queue],'\nserver_state:\n',server_state,
                  '\n\nmaster_clock:\n',master_clock,'\n')
            continue
    if event_now[1] =='delayedoff':
        temp = find_delayedoff_server(server_state, master_clock)
#         print(temp)
        server_state[temp][0]= '0'
        server_state[temp][1]= 0
        
# mean response time
for i in range(len(arrival)):
    mrt += complete_time[i]-arrival[i]
mrt = ('%.3f' %(mrt/len(arrival))) # mean response time

# print('\nfinished!\n','each jobs finished at:',complete_time,'mrt is :',mrt)
print('\nfinished!\n','mrt is :',mrt)
# Out:
# event: [(10, 'arrival'), (20, 'arrival'), (32, 'arrival'), (33, 'arrival')]
#
# -----------------------  -----------------------
# event:
#  [(20, 'arrival'), (32, 'arrival'), (33, 'arrival'), (60.0, 'setup')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['0', 0], 2: ['1', 60.0], 3: ['0', 0]})
#
# depatcher_queue:
#  [('1', 'MARKED')]
#
# master_clock: 10
#
# -----------------------  -----------------------
# event:
#  [(32, 'arrival'), (33, 'arrival'), (60.0, 'setup'), (70.0, 'setup')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['0', 0], 2: ['1', 60.0], 3: ['1', 70.0]})
#
# depatcher_queue:
#  [('1', 'MARKED'), ('2', 'MARKED')]
#
# master_clock: 20
#
# -----------------------  -----------------------
# event:
#  [(33, 'arrival'), (60.0, 'setup'), (70.0, 'setup'), (82.0, 'setup')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['1', 82.0], 2: ['1', 60.0], 3: ['1', 70.0]})
#
# depatcher_queue:
#  [('1', 'MARKED'), ('2', 'MARKED'), ('3', 'MARKED')]
#
# master_clock: 32
#
# -----------------------  -----------------------
# event:
#  [(60.0, 'setup'), (70.0, 'setup'), (82.0, 'setup')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['1', 82.0], 2: ['1', 60.0], 3: ['1', 70.0]})
#
# depatcher_queue:
#  [('1', 'MARKED'), ('2', 'MARKED'), ('3', 'MARKED'), ('4', 'UNMARKED')]
#
# master_clock: 33
#
# -----------------------  -----------------------
# event(setup):
#  [(70.0, 'setup'), (82.0, 'setup'), (61.0, 'completed')]
# depatcher_queue:
#  [('2', 'MARKED'), ('3', 'MARKED'), ('4', 'UNMARKED')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['1', 82.0], 2: ['2', 61.0], 3: ['1', 70.0]})
#
# master_clock:
#  60.0
#
# -----------------------  -----------------------
# event(complete,marked)
# : [(70.0, 'setup'), (82.0, 'setup'), (63.0, 'completed')]
#
# depatcher_queue:
#  [('3', 'MARKED'), ('4', 'MARKED')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['1', 82.0], 2: ['2', 63.0], 3: ['1', 70.0]})
#
# master_clock:
#  61.0
#
# -----------------------  -----------------------
# event(complete,marked)
# : [(70.0, 'setup'), (66.0, 'completed')]
#
# depatcher_queue:
#  [('4', 'MARKED')]
# server_state:
#  defaultdict(<class 'list'>, {1: ['0', 0], 2: ['2', 66.0], 3: ['1', 70.0]})
#
# master_clock:
#  63.0
#
# -----------------------  -----------------------
# event(complete,marked)
# : [(70.0, 'completed')]
#
# depatcher_queue:
#  []
# server_state:
#  defaultdict(<class 'list'>, {1: ['0', 0], 2: ['2', 70.0], 3: ['0', 0]})
#
# master_clock:
#  66.0
#
# -----------------------  -----------------------
# event(complete,else):
#  [(170.0, 'delayedoff')]
#
# depatcher_queue:
#  []
# server_state:
#  defaultdict(<class 'list'>, {1: ['0', 0], 2: ['3', 170.0], 3: ['0', 0]})
#
# master_clock:
#  70.0
#
# -----------------------  -----------------------
#
# finished!
#  mrt is : 41.250

# %%
import wrapper
simulate.run_series()
# Out:
# test 1:
# mode,servers,setup_time,delayoff_time,arr_list,ser_list:
#  trace 3 50 100 [10, 20, 32, 33] [1, 2, 3, 4]
#
# finished!
# mrt is :41.250
#
# test 2:
# mode,servers,setup_time,delayoff_time,time_end,arr_list,ser_list:
#  random 3 50 100 1000 0.35 1.0
#
# finished!
# mrt is :5.172

# %%
import math
import random

def nextTime(rateParameter):
    return -math.log(1.0 - random.random()) / rateParameter

sum([nextTime(1/10) for i in range(1000000)]) / 1000000
# sum([random.expovariate(0.35) for i in range(1000000)]) / 1000000

def generate_exp(T_end, arrival, service):
    arrival_list = []
    service_list = []
    arr , ser = 0.0, 0.0 
    arr += nextTime(arrival)
    while arr<= T_end:
        arrival_list.append(arr)
        ser = nextTime(service)+nextTime(service)+nextTime(service)
        service_list.append(ser)
        arr += nextTime(arrival)
    return arrival_list,service_list
    print(len(arrival_list) == len(service_list))
arr,ser = generate_exp(2000,0.35,1)

sum([nextTime(0.35) for i in range(1000000)]) / 1000000
# Out:
# 2.853748783574223

# %%
import simulate
simulate.run_series()
# Out:
# test 1:
# mode,servers,setup_time,delayoff_time,arr_list,ser_list:
#  trace 3 50 100 [10, 20, 32, 33] [1, 2, 3, 4]
#
# finished!
# mrt is :41.250
#
# test 2:
# mode,servers,setup_time,delayoff_time,time_end,arr_list,ser_list:
#  random 3 50 100 1000 0.35 1.0
#
# finished!
# mrt is :5.132
#
# test 3:
# mode,servers,setup_time,delayoff_time,time_end,arr_list,ser_list:
#  random_fix 3 50 100 1000 0.35 1.0
#
# finished!
# mrt is :5.908
#
# test 4:
# mode,servers,setup_time,delayoff_time,time_end,arr_list,ser_list:
#  random_fix 4 30 50 5000 0.7 1.0
#
# finished!
# mrt is :3.572
#
# test 5:
# mode,servers,setup_time,delayoff_time,time_end,arr_list,ser_list:
#  random_fix 5 5 10 1000 0.5 1.0
#
# finished!
# mrt is :3.922
